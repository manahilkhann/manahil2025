# %% [markdown]
# ---
# layout: post
# types: hacks
# title: Lesson Homework and Popcorn Hacks
# description: hw and popcorn hacks
# toc: true
# comments: true
# ---

# %% [markdown]
# # Digital Divide
# - Popcorn Hack 1: Identify one area (e.g., education, employment, healthcare, or community participation) where you’ve seen the digital divide in action. How does it affect people in different socioeconomic backgrounds?
# - Popcorn Hack 2: Can you think of a computing innovation that might unintentionally exclude certain groups? Why might that happen?
#
# ---
#
# ## Popcorn Hack 1
# - A huge divide is seen in education. Students from lower-income backgrounds often lack reliable access to high-speed internet, personal computers, or even a quiet place to study. This puts them at a huge disadvantage compared to their peers who have access to these resources.
# - The digital divide in education reinforces existing socioeconomic disparities, making it harder for lower-income students to compete in higher education, eventually leading to dificulty getting a job in the future.
#
# ---
#
# ## Popcorn Hack 2
# - Lots of face ID recognizes lighter skinned individuals than darker skinned. This can unintentionally exclude certain people, heightening the divide.
#
# ---
#
# ## Homework Hack
# Write 5 sentences describing what you have noticed about the digital divide in your own community. Consider how socioeconomic factors, location, and access to technology may play a role. Then explain how you can personally help bridge this gap—perhaps through awareness, advocating for policy changes, or supporting community-based tech programs. Make sure each sentence provides a clear insight or action step. Submit your 5 sentences in the next class.
#
# - In my community, personally, I dont think there is that great of a digital divide. This is because the area we live in has many middle-upper class families who are able to afford and attain such resources. However, if you were to compare our community with others, you could see that we have a greater access to technology due to economic factors. To help these communites our community could go and donate old or unused devices and more to aid those in need. With this, the people will have access to more resources, closing the digital divide.
#
# ---

# %% [markdown]
# # Crowdsourcing
#
# ## Popcorn Hack 1
# What are the different types of crowdsourcing, and how do they contribute to innovation? Provide a brief description
#
# 1. Crowdfunding
#     - Purpose: Raising money by collecting small contributions from a large group of people.
#     - Examples: Kickstarter, GoFundMe, Indiegogo.
#     - Use Case: A startup company seeking funds to launch a new product.
#
# 2. Crowd Creation
#     - Purpose: Gathering creative input from a crowd, often for content generation or design.
#     - Examples: Threadless (design competitions), Wikipedia (content creation).
#     - Use Case: A company asking graphic designers to submit logo ideas.
# 3. Crowd Voting
#     - Purpose: Collecting public opinion or feedback to make decisions or rank options.
#     - Examples: Reddit upvotes, talent show voting systems.
#     - Use Case: A company asking users to vote on their next product color.
# 4. Crowd Wisdom
#     - Purpose: Using collective intelligence for decision-making or problem-solving.
#     - Examples: Prediction markets, Stack Overflow, Quora.
#     - Use Case: Gathering expert opinions to forecast stock market trends.
#
#
# ## Popcorn Hack 2
# What is data crowdsourcing, and how does it contribute to open-source development? Provide 3+ examples of public datasets that have been created through crowdsourcing efforts.
#
# - Data crowdsourcing is a method of collecting data from a large group of people, typically through online platforms. It involves the collaboration of many individuals to gather, verify, or analyze information. It contributes to open-source devlopment because it increases dataset diversity, improves accuracy, and encourages collaboration. 3 examples are wikipedia, google maps, and Amazon Mechanical Turk.
#
#
# ## Popcorn Hack 3
# How does distributed computing contribute to innovations through crowdsourcing? Provide 3+ examples of successful projects that have utilized distributed computing and crowdsourcing to obtain data.
#
# - Distributed computing is a model where a task is divided and processed by multiple computers or devices connected over a network. Its purpose is to harness the combined processing power and resources of multiple machines to handle large or complex tasks more efficiently. Some examples of Distributed Computing include: SETI@home, Bitcoin Mining, and Cloud Computing (e.g., Amazon AWS, Google Cloud)
#
#
# ## Homework Hack
# Write 4+ sentences on the impact of crowdsourcing on modern innovation.
# Should cover: Crowdsourcing and its significance in today’s age, The different types of crowdsourcing, How distributed computing enhances crowdsourcing efforts, and How data crowdsourcing has contributed to open source development.
# Then reflect in a sentence or two on the future potential of crowdsourcing in driving innovation.
#
# - Crowdsourcing has become a powerful and useful tool in modern innovation. It allows individuals and organizations to solve complex problems by coming together and with collective intelligence. Distributed computing further enhances crowdsourcing by allowing people to contribute for large-scale projects. Additionally, data crowdsourcing has played a crucial role in open-source development, providing diverse and expansive datasets that improve AI models and more. In the future, crowdsourcing has great potential especially in fields like AI, environmental monitoring, and citizen science. As technology evolves,  collaboration between humans and AI through crowdsourcing could give us access to solutions of great challenges.
#
# ---

# %% [markdown]
# # Legal Ethical Concerns
#
# ## Popcorn Hack 1
#
# What is a legal concern that arises when sharing/using code?
#
# - copyright
# - violating software lisences
# - using code from a repo without a lisence
#
# What is an ethical concern that arises when sharing/using code?
#
# - exploiting open source code
# - ignoring lisences
# - profiting off of someone else's code
#
# ---
#
# ## Popcorn Hack 2
#
# You're building an open-source lyric guessing app. You want it to spread fast, but also don’t want big corporations to steal your work (without giving you credit!). Which license do you pick?
#
# - MIT: Good for fast growth/spread of your code, but allows anyone to reuse your code however they wantGPL because its open source and gives you credit.
# - GPL:  Protects your work by requiring anyone who modifies/distributes it to also share their changes as open source.
# - Apache 2.0: Allows a wide range of use, but also offers a patent clause, to protect you from legal issues
#
# ---
#
# ## Homework Hack
#
# <img src="{{site.baseurl}}images/Legal&EthicalConcernsHwHack.png" width = "500" height = "300"/>
#
# ---

# %% [markdown]
# # Safe Computing
#
# ## Popcorn Hack 1
#
# <img src="{{site.baseurl}}images/SafeComputingPopcornHack1.png" width = "500" height = "300"/>
#
# ---
#
# ## Popcorn Hack 2
#
# <img src="{{site.baseurl}}images/TrafficLights.png" width = "500" height = "300"/>
#
# - row 1, column 3
# - row 2, column 2
# - row 2 column 3
#
# ---
#
# ## Homework Hack 1
#
# <img src="{{site.baseurl}}images/SafeComputingHw.png" width = "500" height = "300"/>
#
# ---
#
# ## Homework Hack 2

# %%
import random

def caesar_cipher(text, shift, mode):
    result = ""
    for char in text:
        if char.isalpha():  # This part of the code only encrypts letters
            shift_amount = shift if mode == "encrypt" else -shift
            new_char = chr(((ord(char.lower()) - 97 + shift_amount) % 26) + 97)
            result += new_char.upper() if char.isupper() else new_char
        else:
            result += char  # this keeps the spaces and position unchanged
    return result

# Here is the code for getting the user input
mode = input("Do you want to encrypt or decrypt? ").strip().lower()
message = input("Enter your message: ")
shift_input = input("Enter shift value (number of places to shift or 'random'): ").strip().lower()

# Determine shift value
if shift_input == "random":
    shift = random.randint(1, 25)
    print(f"Random shift value chosen: {shift}")
else:
    shift = int(shift_input)

# And finally the code performs the encryption/decryption
output = caesar_cipher(message, shift, mode)
print(f"Result: {output}")

# %% [markdown]
# ---

# %% [markdown]
# # Binary Search Algorithm
#
# ## Popcorn Hack 1
#
# <table style="width:100%; border-collapse: collapse; text-align: left;">
#   <tr style="background-color:rgba(139, 181, 207, 0.57);">
#     <th style="padding: 10px; border: 1px solid #ddd;">Binary Digit</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">2⁷</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">2⁶</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">2⁵</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">2⁴</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">2³</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">2²</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">2¹</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">2⁰</th>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;"><b>Example:</b></td>
#     <td style="padding: 10px; border: 1px solid #ddd;">0</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">0</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">0</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">1</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">1</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">0</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">0</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">1</td>
#   </tr>
# </table>
#
#
# ## Popcorn Hack 2
#
# - 10 = 1010
#     - 10 ÷ 2 = 5, remainder = 0
#     - 5 ÷ 2 = 2, remainder = 1
#     - 2 ÷ 2 = 1, remainder = 0
#     - 1 ÷ 2 = 0, remainder = 1
#
#
# - 15 = 1111
#     - 15 ÷ 2 = 7, remainder = 1
#     - 7 ÷ 2 = 3, remainder = 1
#     - 3 ÷ 2 = 1, remainder = 1
#     - 1 ÷ 2 = 0, remainder = 1
#
#
# - 17 = 10001
#     - 17 ÷ 2 = 8, remainder = 1
#     - 8 ÷ 2 = 4, remainder = 0
#     - 4 ÷ 2 = 2, remainder = 0
#     - 2 ÷ 2 = 1, remainder = 0
#     - 1 ÷ 2 = 0, remainder = 1
#
# ## Popcorn Hack 3
#
# - Linear Search: Check each element one by one.
# - Binary Search: Compare with the middle element and narrow down the search by halving the list.
#
# ---
#
# ## Homework Hack
#
# ### Part A
# - 42/2=21 R0
# - 21/2=10 R1
# - 10/2= 5 R0
# - 5/2 = 2 R1
# - 2/2=1 R0
# - 1/2= 0 R1
#
# #### 42 =101010
#
# - 19/2= 9 R1
# - 9/2= 4 R1
# - 4/2= 2 R0
# - 2/2=1 R0
# - 1/2= 0 R1
#
# #### 19 = 10011
#
# - 100/2= 50 R0
# - 50/2= 25 R0
# - 25/2= 12 R1
# - 12/2= 6 R0
# - 6/2 = 3 R0
# - 3/2= 1 R1
# - 1/2= 0 R1
#
# #### 100 = 1100100
#
# ## Part B:
#
# - 101010
#     - 2^0+2^1+2^2+2^3+2^4+2^5= 2+8+32= 42
#     - You start from the right and go to the left. Every time there is a zero, you dont' add that to the overall total sum. Therefore you would only include 2^1, 2^3, and 2^5.
#
# - 10011
#     - 2^0+2^1+2^2+2^3+2^4= 1+2+16= 19
#     - You start from the right and go to the left. Every time there is a zero, you dont' add that to the overall total sum. Therefore you would only include 2^0, 2^1, and 2^4.
#
# - 110011
#     - 2^0+2^1+2^2+2^3+2^4+2^5= 1+2+16+32= 51
#     - You start from the right and go to the left. Every time there is a zero, you dont' add that to the overall total sum. Therefore you would only include 2^0, 2^1, 2^4, and 2^5.
#
# ## Part C:
#
# <img src="{{site.baseurl}}images/BinaryTable.png" width = "500" height = "300"/>
#
#
# The above table walks through my steps for finding each indicated target number. All of the numbers except for 5 could be found, since 5 is not within the given list of numbers, and would lead to the loop ending before the number is found.
#
# ## Part D:
#
# <img src="{{site.baseurl}}images/BinaryTable2.png" width = "500" height = "300"/>
#
# Similar to the previous part, all indicated items were found except for the last one. The only difference that made the steps a little more confusing or difficult was translating from the numbers (0 to 10) and then back to the words (the fruits).
#
# ## FRQ Response:
#
# Why is binary search more efficient for large data than linear search?
# - Binary search is much more efficient because it repeatedly cuts large data sets in half. We can also explain this using the dictionary example. It is a lot easier to split the book in half and then go either left or right from that point than to read through every single word. Reading through every single word would be an example of linear searching, which is not time or cost-efficient.
#
# ---
#
# What happens if the list isn’t sorted and you try to use binary search?
# - If the list is not sorted, binary searching would not work, and as a result, the algorithm would most likely return the false target or just completely fail to find the target. In order for binary to be able to divide the data sets provided, the data needs to flow in some sort of logical sense (ascending, descending, etc).
#
# ---
#
# Could you use binary search in a video game leaderboard or streaming service search bar? Why or why not?
# - Yes, you could use binary search for a video game leaderboard. Video game sites tend to have many users that you can view, and leaderboard data is always sorted. This sorting can be by who has the highest rank, most points, most games played, etc. Because of this, video games have both sorted and large amounts of data, causing binary searching to be applicable. However, it may not be the best choice for a streaming service search bar since the data is a lot more unsorted and randomized based on user preference, trendingness, watch history, etc.
#
# ---

# %% [markdown]
# # Lists and Filtering Algorithms
#
# ## Popcorn Hack 1
#
# - Benefits of using a list:
#     - Store lots of data in one place
#     - Access each item individually
#     - Filter, sort, and organize that data
# - Real world example:
#     - online shopping cart
#     - spotify playslist
#
# ---
#
# ## Popcorn Hack 2
#
# - This code outputs eraser
#
# ---
#
# ## Popcorn Hack 3
#
# - Real world examples of filtering algorithms:
#     - Inbox → email is unread → Unread emails only (new list)
#     - Online Shopping → price < $20 → Discounted items (new list)
#     - Spotify → Artist == "Singer A" → Only songs by Singer A (new list)
#
# ---
#
# ## Homework Hack

# %%
# 1. Create a list that includes at least five items
# We'll use a list of fruits

fruits = ["apple", "banana", "cherry", "mango", "grape"]

# --- List Procedure 1: Append ---
# Add an item to the end of the list
fruits.append("orange")  # Adds "orange" to the end of the fruits list

# --- List Procedure 2: Remove ---
# Remove a specific item from the list
fruits.remove("banana")  # Removes "banana" from the list

# --- List Procedure 3: Sort ---
# Sort the list alphabetically
fruits.sort()  # Sorts the list of fruits in alphabetical order

# View the final list after modifications
print("Updated fruits list:", fruits)

# 2. List Traversal Instructions
# We'll use a for-loop to go through each item

print("\nTraversing the fruits list:")
for fruit in fruits:
    print("Current fruit:", fruit)

# 3. Filtering Algorithm (Using pandas)
import pandas as pd

# Start with a list of fruit prices (simulate a mini database)
fruit_data = {
    "Fruit": ["apple", "banana", "cherry", "mango", "grape", "orange"],
    "Price": [0.99, 0.50, 2.00, 1.50, 2.50, 0.80]
}

# Create a pandas DataFrame from the dictionary
df = pd.DataFrame(fruit_data)

# Define a condition: filter fruits that cost more than $1.00
expensive_fruits = df[df["Price"] > 1.00]

# Show the filtered DataFrame
print("\nFruits that cost more than $1.00:")
print(expensive_fruits)

# %% [markdown]
# ### Final Reflection
# - In real life, filtering algorithms are used to sort out important information, like finding emails from a specific person.
# - Lists and filtering help us organize and find data quickly, whether it's searching through contacts or choosing products under a certain price online.
#
# ---

# %% [markdown]
# # Simulation/Games and Random Algorithms
#
# ## Popcorn Hack #1
# - Games: Dice rolls, card shuffling, enemy behavior
# - Simulations: Weather models, traffic patterns, economic scenarios
#
# ## Popcorn Hack #2

# %%
import random

def magic_8_ball():
    spin = random.randint(1, 4)  # Generates a number from 1 to 4
    if spin == 1 or spin == 2:
        return "Yes"  # 2 out of 4 = 50%
    elif spin == 3:
        return "No"   # 1 out of 4 = 25%
    else:
        return "Ask again later"  # 1 out of 4 = 25%

# Test your function
for i in range(10):
    print(f"Magic 8-Ball says: {magic_8_ball()}")

# %% [markdown]
# ## Popcorn Hack #3

# %%
# Traffic light simulation (updated durations)

states = ["Green", "Yellow", "Red"]
durations = {"Green": 5, "Yellow": 2, "Red": 4}
timeline = []

# Simulate 20 time steps
time = 0
state = "Green"
counter = 0

while time < 20:
    timeline.append((time, state))
    counter += 1
    if counter == durations[state]:
        counter = 0
        current_index = states.index(state)
        state = states[(current_index + 1) % len(states)]
    time += 1

for t, s in timeline:
    print(f"Time {t}: {s}")

# %% [markdown]
# This is a simulation because it models the behavior of a traffic light over time using code, allowing us to observe how states change without using a physical light. In the real world, this kind of simulation helps traffic engineers design better signal timing to improve safety, reduce congestion, and optimize traffic flow at intersections.
#
# ## Homework Hack

# %%
import random

def roll_dice():
    """Roll two dice and return their values and sum."""
    die1 = random.randint(1, 6)
    die2 = random.randint(1, 6)
    total = die1 + die2
    print(f"You rolled: {die1} + {die2} = {total}")
    return total

def play_dice_game():
    """
    Play one round of the dice game.
    Returns True if player wins, False if player loses.
    """
    first_roll = roll_dice()

    if first_roll in [7, 11]:
        print("You win!")
        return True
    elif first_roll in [2, 3, 12]:
        print("You lose!")
        return False
    else:
        point = first_roll
        print(f"Your point is: {point}")
        while True:
            roll = roll_dice()
            if roll == point:
                print("You rolled your point! You win!")
                return True
            elif roll == 7:
                print("You rolled a 7! You lose!")
                return False

def main():
    """Main game function with game loop and statistics."""
    wins = 0
    losses = 0

    while True:
        play = input("\nDo you want to play a round? (yes/no): ").lower()
        if play == "yes":
            if play_dice_game():
                wins += 1
            else:
                losses += 1
            print(f"Current Stats → Wins: {wins}, Losses: {losses}")
        elif play == "no":
            print(f"\nFinal Stats → Wins: {wins}, Losses: {losses}")
            print("Thanks for playing!")
            break
        else:
            print("Please enter 'yes' or 'no'.")

if __name__ == "__main__":
    print("🎲 Welcome to the Dice Game!")
    main()

# %% [markdown]
# ---

# %% [markdown]
# # Big O and Algorithim Efficiency
#
# ## Popcorn Hack #1
# The two strategies that are most effective are 2 and 3 because for 2 when checking if 2 is the last digit you're only checking one digit out of five options which is quicker in processing. 3 is effective because it is only one step because if it is 0 you already know its divisible by two.
#
# 2. Check if the last digit is 0, 2, 4, 6, or 8 manually
# 3. Use the modulus operator (%) to check if the remainder when divided by 2 is 0
#
# ## Popcorn Hack #2
# - What is the time complexity of each algorithm?
#     - O(n) - Linear Search, O(log n) - Binary Search
# - How many times faster is binary search than linear search?
#     - linear: 4.11, binary: 0.011 binary is 34,000 x faster
# - What happens if you increase data_size to 20000000?
#     - the time doubled, binary was faster by 30,000 x
#
# ## Homework Hack #1

# %%
import random
import time

# Bubble Sort
def bubble_sort(arr):
    n = len(arr)
    for i in range(n):
        for j in range(0, n-i-1):
            if arr[j] > arr[j+1]:
                arr[j], arr[j+1] = arr[j+1], arr[j]

# Merge Sort
def merge_sort(arr):
    if len(arr) > 1:
        mid = len(arr) // 2
        left = arr[:mid]
        right = arr[mid:]
        merge_sort(left)
        merge_sort(right)

        i = j = k = 0
        while i < len(left) and j < len(right):
            if left[i] < right[j]:
                arr[k] = left[i]
                i += 1
            else:
                arr[k] = right[j]
                j += 1
            k += 1
        while i < len(left):
            arr[k] = left[i]
            i += 1
            k += 1
        while j < len(right):
            arr[k] = right[j]
            j += 1
            k += 1

# Generate a list of 100 random numbers between 1 and 1000
original_list = [random.randint(1, 1000) for _ in range(100)]

# Time Bubble Sort
bubble_list = original_list.copy()
start_bubble = time.time()
bubble_sort(bubble_list)
end_bubble = time.time()
bubble_time = end_bubble - start_bubble

# Time Merge Sort
merge_list = original_list.copy()
start_merge = time.time()
merge_sort(merge_list)
end_merge = time.time()
merge_time = end_merge - start_merge

# Output the results
print(f"Bubble Sort Time: {bubble_time:.6f} seconds")
print(f"Merge Sort Time: {merge_time:.6f} seconds")

if merge_time < bubble_time:
    print("Merge Sort is faster.")
else:
    print("Bubble Sort is faster.")

# %% [markdown]
# ### Final Question
# Merge Sort consistently outperforms Bubble Sort because it uses a divide-and-conquer approach that breaks the list into smaller parts and merges them efficiently, resulting in a time complexity of O(n log n). In contrast, Bubble Sort repeatedly compares and swaps adjacent elements, leading to a much slower O(n²) time complexity. As the list size grows, the performance gap between the two algorithms becomes significantly more noticeable.
#
# ## Homework Hack #2

# %%
import random

# Linear Search
def linear_search(arr, target):
    count = 0
    for i in range(len(arr)):
        count += 1
        if arr[i] == target:
            return count
    return -1

# Binary Search
def binary_search(arr, target):
    left, right = 0, len(arr) - 1
    count = 0
    while left <= right:
        count += 1
        mid = (left + right) // 2
        if arr[mid] == target:
            return count
        elif arr[mid] < target:
            left = mid + 1
        else:
            right = mid - 1
    return -1

# Generate sorted list from 1 to 100,000
arr = list(range(1, 100001))

# Pick a random number from the list
target = random.choice(arr)

# Run both search functions
linear_comparisons = linear_search(arr, target)
binary_comparisons = binary_search(arr, target)

# Output results
print(f"Target Number: {target}")
print(f"Linear Search Comparisons: {linear_comparisons}")
print(f"Binary Search Comparisons: {binary_comparisons}")

# %% [markdown]
# ### Final Questions
# 1. Which search algorithm is faster, and why?
# Binary Search is faster because it uses a divide-and-conquer method to repeatedly cut the search space in half, giving it a time complexity of O(log n). In contrast, Linear Search checks each element one by one, resulting in a slower O(n) time complexity, especially in large lists.
#
# 2. What happens if you run both searches on an unsorted list?
# Linear Search will still work correctly, since it doesn’t depend on the order of elements — it just checks each item until it finds the target.
# However, Binary Search will fail or return incorrect results on an unsorted list, because it relies on the list being sorted to correctly eliminate half the search space each step.
#
# ---

# %% [markdown]
# # Undecideable Problems, Graphs + Heuristics
#
# ## Popcorn Hack #1
# There is an undecidable problem above because it keeps increasing and doesn't come back to 0
#
# ## Popcorn Hack #2
#
# 1. False, if the problem is undecidable then there will be no algorithm that can create a yes/no output for all inputs
# 2. False, an undecidable problem that only works sometimes and will ot work overall
#
# ## Homework Hack
#
# ### Part 1
# “Is this number divisible by 2?”
# → Decidable
# Reason: You can easily check if a number is divisible by 2 by looking at its last digit or using simple division.
#
# “Will this program stop or run forever?”
# → Undecidable
# Reason: This is the famous Halting Problem — proven by Alan Turing that no general algorithm can solve it for all programs.
#
# “Does this sentence contain the word ‘banana’?”
# → Decidable
# Reason: You can scan the sentence in a finite amount of time and check if "banana" appears.
#
# “Will this AI ever become sentient?”
# → Undecidable
# Reason: There’s no guaranteed way to predict future complex behavior like sentience with an algorithm.
#
# ### Part 2
# Algorithm 1 (Input a number, say "Yes" if even, "No" if odd)
# → Decidable
# Reason: It's simple — you can check if a number is even in a finite number of steps every time.
#
# Algorithm 2 (Input a program, predict if it stops or runs forever)
# → Undecidable
# Reason: Again, this is the Halting Problem, and it’s impossible to always know for sure if an arbitrary program halts.
#
# ### Part 3
# Example:
# Falling in love — You can’t predict exactly how a relationship will turn out until you live through it.
# (Other examples could be starting a new job, traveling to a new place, or raising a pet.)
#
# ---
#
# # Graphs
#
# ## Popcorn Hack
# <img src="{{site.baseurl}}images/graph.png" width = "500" height = "300"/>
#
# ## Homework Hack
#
# Q1: In which of the configurations is it possible to have redundant routing between devices Q and V?
#
# A. Configuration I only
#
# Q2: In configuration I, what is the minimum number of connections that must be broken or removed before device T can no longer communicate with device U?
#
# B. Two
#
# # Heuristics
#
# ## Popcorn Hack

# %%
def greedy_coin_change(amount, coins=[1, 5, 10, 25]):
    change = []
    for coin in coins:
        while amount >= coin:
            amount -= coin
            change.append(coin)
    return change

# Example usage:
amount = 63
result = greedy_coin_change(amount)
print(f"Change for {amount}¢: {result}")
print(f"Total coins used: {len(result)}")

# %% [markdown]
# ## Homework Hack
# Changing the order of the coins made the greedy algorithm much less efficient, because it picked too many small coins instead of larger ones. The original algorithm that started with the largest coins used fewer coins overall. Greedy algorithms work well when the biggest choice is always the best, but they can fail when a better overall solution requires smaller or different steps.
#
# ---

# %% [markdown]
# # Binary
#
# ## Popcorn Hack 1: Examples for Identifying Binary
# - Example 1: Number: 101010
#     - this is binary because it only has 1 and 0
# - Example 2: Number: 12301
#     - not binary because has numbers other than 1 and 0=
# - Example 3: Number: 11001
#     - this is binary because it only has 1 and 0
#
# ## Popcorn Hack 2: Examples for Adding and Subtracting Binary
# - Example 1 (Adding): Binary Numbers: 101 + 110
#     - 1 + 0 = 1, 0 + 1 = 1, 1 + 1 = 10 (carry over 1). Result: 1011.
# - Example 2 (Subtracting): Binary Numbers: 1101 - 1011
#     - 1 - 1 = 0, 0 - 1 requires borrowing, 10 - 0 = 10, 1 - 1 = 0. Result: 010.
# - Example 3 (Adding): Binary Numbers: 111 + 1001
#     - 1 + 1 = 10 (carry over 1), 1 + 0 + 1 = 10 (carry over 1), 1 + 0 + 1 = 10 (carry over 1). Result: 1110.
#
# # Logic Gates
#
# ## Popcorn Hack #1
# - What will be the result of this expression? True or False and False
#     - Since AND has higher priority than OR, the expression is evaluated as: True
#
# ## Popcorn Hack #2
# - What will be the result of this expression? not True and False
#     - Without parentheses, the NOT operator is evaluated first due to its higher priority, followed by the AND operator: False
#
# ## Popcron Hack #3
# - What will be the result of this expression? True or False and not False
#     - Without parentheses, the AND and NOT operators are evaluated first due to their higher priority: True
#
# ## Homework Hack #1

# %%
def decimal_to_binary(n):
    """Converts a decimal number to binary (string)."""
    if n == 0:
        return "0"
    elif n > 0:
        return bin(n)[2:]  # Strip the '0b' prefix
    else:
        return "-" + bin(-n)[2:]

def binary_to_decimal(b):
    """Converts a binary string to a decimal number."""
    if b.startswith('-'):
        return -int(b[1:], 2)
    else:
        return int(b, 2)

# Test cases
test_decimals = [0, 5, 10, -7, -15]
test_binaries = ["0", "101", "1010", "-111", "-1111"]

print("Decimal to Binary:")
for num in test_decimals:
    print(f"{num} → {decimal_to_binary(num)}")

print("\nBinary to Decimal:")
for b in test_binaries:
    print(f"{b} → {binary_to_decimal(b)}")

# %% [markdown]
# Example Input/Output:

# %%
Decimal to Binary:
0 → 0
5 → 101
10 → 1010
-7 → -111
-15 → -1111

Binary to Decimal:
0 → 0
101 → 5
1010 → 10
-111 → -7
-1111 → -15

# %% [markdown]
# ## Homework Hack #2

# %%
import time

valid_difficulties = {"easy", "medium", "hard"}

difficulty = input("Enter difficulty (easy, medium, hard): ").lower().strip()

while difficulty not in valid_difficulties:
    print("Please enter a valid difficulty level.")
    time.sleep(0.5)
    difficulty = input("Enter difficulty (easy, medium, hard): ").lower().strip()

print("Difficulty set to:", difficulty)

# %% [markdown]
# ---

# %% [markdown]
# # Color Codes and Base 64
#
# ## Popcorn Hack #1
# 1.  Which image format is best for logos and transparency?
#     - PNG (PNG supports transparency and preserves image quality.)
# 2.  Which format loses quality to make the file size smaller?
#     - JPG / JPEG (JPEG uses lossy compression to shrink file size.)
# 3. Which format is used for simple animations, like memes?
#     -  GIF (GIF supports basic animations and limited color.)
#
# ## Popcorn Hack #2
# U1Q= → ST
# - U = 20 → 010100
# - 1 = 53 → 110101
# - Q = 16 → 010000
# Together = 01010011 01010100 = ASCII for "ST"
#
# ## Homework Hack #1

# %% [markdown]
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#   <style>
#     body {
#       font-family: Arial, sans-serif;
#       padding: 20px;
#       background: #f4f4f4;
#     }
#     .color-block {
#       width: 200px;
#       height: 100px;
#       margin: 10px;
#       padding: 10px;
#       font-weight: bold;
#       display: flex;
#       align-items: center;
#       justify-content: center;
#       border-radius: 8px;
#       box-shadow: 0 2px 6px rgba(0,0,0,0.2);
#     }
#     .container {
#       display: flex;
#       flex-wrap: wrap;
#     }
#   </style>
# </head>
# <body>
#   <div class="container">
#     <div class="color-block" style="background-color: #9F84BD; color: #fff;">#9F84BD</div>
#     <div class="color-block" style="background-color: #C09BD8; color: #fff;">#C09BD8</div>
#     <div class="color-block" style="background-color: #EBC3DB; color: #000;">#EBC3DB</div>
#     <div class="color-block" style="background-color: #EDE3E9; color: #000;">#EDE3E9</div>
#     <div class="color-block" style="background-color: #E6E4CE; color: #000;">#E6E4CE</div>
#   </div>
# </body>
# </html>

# %% [markdown]
# ## Homework Hack #2

# %% [markdown]
# <html lang="en">
# <head>
#     <meta charset="UTF-8">
# </head>
# <body>
#     <img src="data:image/jpeg;base64,..." alt="Inline Image">
# </body>
# </html>
