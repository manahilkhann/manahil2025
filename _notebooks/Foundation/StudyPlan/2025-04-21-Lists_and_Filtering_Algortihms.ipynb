# %% [markdown]
# ---
# layout: post
# types: hacks
# title: Lists and Filtering
# description:
# toc: true
# comments: true
# ---

# %% [markdown]
# #  What is a List?
#
# **College Board Definition**:
# A list is an ordered sequence of elements. The use of lists allows multiple related items to be represented using a single variable.
#
# ## What does this mean?
# A list holds multiple things in one variable, like a basket holding several items.
#
# ---
#
# # What's wrong with this method?
#
# ```python
# score1 = 87
# score2 = 90
# score3 = 85
# score4 = 70
# score5 = 80

# %% [markdown]
# # Basic List Operations
#
# ```python
# cars = ["Jaguar", "Ford", "Kia"]
# cars[1] = "Rivian"           # Modify
# cars.append("BMW")          # Add at end
# cars.insert(1, "Mazda")     # Add at position
# cars.pop(0)                 # Remove by index
# print(cars[0:2])            # Slice

# %% [markdown]
# # [Popcorn and Homework Hacks](http://127.0.0.1:4100/manahil2025/2025/03/21/lessons_hw_hacks_IPYNB_2_.html)
