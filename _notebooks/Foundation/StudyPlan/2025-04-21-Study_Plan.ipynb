# %% [markdown]
# ---
# layout: post
# types: hacks
# title: Study Plan
# description: Summaries of all the topics with helpful info for the AP exam!
# toc: true
# comments: true
# ---

# %% [markdown]
# <html lang="en">
# <head>
#   <meta charset="UTF-8" />
#   <meta name="viewport" content="width=device-width, initial-scale=1.0"/>
#   <style>
#     body {
#       font-family: 'Segoe UI', sans-serif;
#       margin: 0;
#       padding: 20px;
#       background-color: rgb(245, 250, 255);
#       color: #333;
#     }
#     h1 {
#       text-align: center;
#       font-size: 2rem;
#       margin-bottom: 1.5rem;
#     }
#     .grid {
#       display: grid;
#       grid-template-columns: repeat(3, 1fr);
#       gap: 20px;
#       margin-bottom: 40px;
#     }
#     .card {
#       background: white;
#       border-radius: 12px;
#       box-shadow: 0 4px 10px rgba(0, 0, 0, 0.05);
#       padding: 20px;
#       text-align: center;
#     }
#     .card h2 {
#       font-size: 1.2rem;
#       margin-bottom: 10px;
#     }
#     .button {
#       display: block;
#       width: 100%;
#       max-width: 220px;
#       margin: 8px auto;
#       padding: 10px;
#       background-color: rgb(157, 177, 216);
#       border: none;
#       border-radius: 8px;
#       cursor: pointer;
#       transition: background-color 0.2s ease;
#       box-sizing: border-box;
#     }
#     .button:hover {
#       background-color: rgb(115, 131, 163);
#     }
#     .content-box {
#       background-color: rgb(213, 228, 243);
#       border-radius: 10px;
#       padding: 20px;
#       box-shadow: 0 0 8px rgba(0, 0, 0, 0.05);
#       margin-top: 20px;
#       display: none;
#     }
#     .content-box.active {
#       display: block;
#     }
#   </style>
# </head>
# <body>
#
# <h1>AP CSP Resource Dashboard</h1>
#
# <div class="grid">
#   <!-- Column 1: College Board Videos -->
#   <div class="card">
#     <h2>College Board Videos</h2>
#     <a href="https://www.youtube.com/watch?v=cs58aO6XczY&list=PLoGgviqq4844vbwcKegJgIxSQyVHDzSXT" target="_blank">
#       <button class="button">Watch Videos</button>
#     </a>
#   </div>
#
#   <!-- Column 2: Big Idea 3 -->
#   <div class="card">
#     <h2>Big Idea 3</h2>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Binary_Search_Algorithm_IPYNB_2_.html" target="_blank">
#       <button class="button" onclick="showContent('Binary Search Algorithm')">Binary Search Algorithm</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Lists_and_Filtering_Algortihms_IPYNB_2_.html" target="_blank">
#       <button class="button" onclick="showContent('Lists and Filtering Algorithms')">Lists and Filtering Algorithm</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Simulation_Games_and_Random_Algorithms_IPYNB_2_.html" target="_blank">
#       <button class="button" onclick="showContent('Simulation/Games and Random Algorithms')">Simulation/Games and Random Algorithms</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/BigO_and_Algorithm_Efficiency_IPYNB_2_.html" target="_blank">
#       <button class="button" onclick="showContent('Big O and Algorithm Efficiency')">Big O and Algorithm Efficiency</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Undecidable_Problems_IPYNB_2_.html" target="_blank">
#       <button class="button" onclick="showContent('Undecideable Problems, Graphs + Heuristics')">Undecideable Problems, Graphs + Heuristics</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Binary_Base2_Math_IPYNB_2_.html" target="_blank">
#       <button class="button" onclick="showContent('Binary Base 2 Math + Logic Gates')">Binary Base 2 Math + Logic Gates</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Color_Codes_IPYNB_2_.html" target="_blank">
#       <button class="button" onclick="showContent('Color Codes/Images/Base64')">Color Codes/Images/Base64</button>
#     </a>
#   </div>
#
#   <!-- Column 3: Big Idea 5 -->
#   <div class="card">
#     <h2>Big Idea 5</h2>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Beneficial_Harmful_Effects_IPYNB_2_.html" target="_blank">
#       <button class="button">Beneficial Harmful Effects</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Digital_Divide_IPYNB_2_.html" target="_blank">
#       <button class="button">Digital Divide</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Computing_Bias_IPYNB_2_.html" target="_blank">
#       <button class="button">Computing Bias</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Crowdsourcing_IPYNB_2_.html" target="_blank">
#       <button class="button" onclick="showContent('Crowdsourcing')">Crowdsourcing</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Legal_Ethical_Concerns_IPYNB_2_.html" target="_blank">
#       <button class="button" onclick="showContent('Legal/Ethical Concerns')">Legal/Ethical Concerns</button>
#     </a>
#     <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Safe_Computing_IPYNB_2_.html" target="_blank">
#       <button class="button" onclick="showContent('Safe Computing')">Safe Computing</button>
#     </a>
#   </div>
# </div>
#
# <!-- Hidden Content Box -->
# <div class="content-box" id="content">
#   <h2 id="content-title"></h2>
#   <p>You selected: <strong id="topic-name"></strong></p>
#   <p>Content for this topic will go here.</p>
# </div>
#
# <script>
#   function showContent(topic) {
#     document.getElementById('content').classList.add('active');
#     document.getElementById('content-title').innerText = topic;
#     document.getElementById('topic-name').innerText = topic;
#   }
# </script>
#
# </body>
# </html>
