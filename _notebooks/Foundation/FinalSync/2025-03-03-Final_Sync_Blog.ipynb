# %% [markdown]
# ---
# layout: post
# types: hacks
# title: Final Sync Blog
# description: My final review!
# toc: true
# comments: true
# ---

# %% [markdown]
# Over the past 12 weeks, I have learnt many things through my journey in computer science, focusing on full-stack development, collaboration methodologies, and project-based learning. Here’s a breakdown of what I accomplished and the challenges I faced along the way.
#
# ---
#
# ## Five Things I Did Over 12 Weeks
# <table style="width:100%; border-collapse: collapse; text-align: left;">
#   <tr style="background-color:rgba(139, 181, 207, 0.57);">
#     <th style="padding: 10px; border: 1px solid #ddd;">Task</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">Description</th>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">
#       <a href="https://github.com/users/Voyager162/projects/3/views/3?pane=issue&itemId=95904747&issue=Voyager162%7CbinaryFrontend%7C1" target="_blank"><b>Project Planning Through Burndown Lists</b></a>
#     </td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Brainstormed ideas, created issues, helped with organization</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">
#       <a href="http://127.0.0.1:4100/manahil_khan_2025/2025/03/03/Backend_Development_&_API_Integration_IPYNB_2_.html" target="_blank"><b>Backend Development & API Integration</b></a>
#     </td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Built APIs, handled authentication, connected the frontend with the database.</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;"><b>CRUD Functionality</b></td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Designed full CRUD in my feature</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">
#       <a href="http://127.0.0.1:4100/manahil_khan_2025/2025/03/03/Backend_Model_IPYNB_2_.html" target="_blank"><b>Backend Model</b></a>
#     </td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Made a model to display the scores and data in a backend table</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;"><b>Team Collaboration</b></td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Learned the importance of collaboration by asking for help and working together</td>
#   </tr>
# </table>
#
# ---
#
#
# ## [Full Stack Project Demo, including CPT requirement highlights](http://127.0.0.1:4887/binary_frontend/leaderboard/){:target="_blank"}
#
#
# ---
#
# <table style="width:100%; border-collapse: collapse; text-align: left;">
#   <tr style="background-color:rgba(139, 181, 207, 0.57);">
#     <th style="padding: 10px; border: 1px solid #ddd;">CPT Requirements</th>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;"><b>Use of at least one list (or other collection type)</b></td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;"><b>At least one procedure contributing to the program's purpose</b></td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;"><b>Algorithm including sequencing, selection, and iteration</b></td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;"><b>Calls to student-developed procedure</b></td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;"><b>Instructions for output</b></td>
#   </tr>
# </table>
#
#
# ---
#
# ## Presentation and Feedback (N@tM)
#
# <style>
#     .image-scroller {
#         width: 100%;
#         overflow-x: scroll;
#         overflow-y: hidden;
#         white-space: nowrap;
#         background-color:rgb(255, 255, 255);
#         border: 1px rgb(255, 255, 255);
#         border-radius: 10px;
#         box-shadow: 0 4px 8px 0 #F0F6F6, 0 6px 20px 0 #F0F6F6;
#         margin: 20px auto;
#         padding: 10px 0;
#     }
#     .image-scroller img {
#         display: inline-block;
#         width: 400px;
#         height: 300px;
#         margin-right: 10px;
#         border-radius: 5px;
#         object-fit: cover;
#     }
# </style>
# <div class="image-scroller">
#     <img src="{{ site.baseurl }}/images/Team.png" alt="Team Photo">
#      <img src="{{ site.baseurl }}/images/N@tM1.png" alt="CSSE 1 Demo" style="margin-left: 10px;">
#     <img src="{{ site.baseurl }}/images/N@tM2.png" alt="CSSE 1 Demo">
#     <img src="{{ site.baseurl }}/images/N@tM3.png" alt="CSP Demo">
# </div>
#
#
# ### Night at the Museum (N@tM) Feedback
#
# <table style="width:100%; border-collapse: collapse; text-align: left;">
#   <tr style="background-color:rgba(139, 181, 207, 0.57);">
#     <th style="padding: 10px; border: 1px solid #ddd;">Full Name</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">Student or Parent?</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">What are some things we did well?</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">What are some things we could improve on?</th>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Serena Chan</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Student</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Spoke to audience weekly & I like the design of the website</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Nothing, you ate it up!!!! (especially Shriya, Manahil, & Justin)</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Kush Kharia</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Student</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Made each page and feature flow cohesively</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Having everyone explain their own features</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Prajna Raj</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Student</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Presentation and actual features</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Color scheme, frontend</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Jowan Elzein</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Student</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">I like how there were quizzes, tests, and games for your features</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">I feel like you could make it more engaging with more features, pictures, or buttons on the home page</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Darsh Darsh</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Student</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Presentation was engaging</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Coordination?</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Soumini Kandula</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Student</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">The UI is really pretty and the game is super fun.</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">The quiz form could be improved to make it a little more aesthetically pleasing</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Nikhil Narayan</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Student</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Presentation</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Speaking</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Joanna Hu</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Student</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Everything works and flows together really well!</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Page is a little bland, add some more frontend pizzazz</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Matthew Wakayama</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Student</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">The design of the website is very cool and slick</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">There’s a lot of binary games out there that could be interesting to incorporate into your website, like logic circuits</td>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Swati Patel</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Parent</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Presentation and passion for project</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Have all team members test out</td>
#   </tr>
# </table>
#
# ---
#
# | Feedback Type             | Comments                                                                        |
# |---------------------------|---------------------------------------------------------------------------------|
# | **Positive Aspects**      | Functionality: Everything works well and flows smoothly. Engagement: The presentation and games were fun and engaging.                         |
# | **Areas for Improvement** | Visuals: Some pages could use a little more styling. Content: Adding more diverse features than binary games could improve it.                     |
# | **Future Considerations** | Plan to add features other than games and improve the styling and visuals to make it more professional and polished |
#
#
# ---
#
# ## [Project Feature Blog Write-Up](http://127.0.0.1:4100/manahil_khan_2025/2025/01/25/Full_Stack_Review_IPYNB_2_.html){:target="_blank"}
#
#
# ---
#
# ## Multiple-Choice Question (MCQ)
#
# <img src="{{site.baseurl}}/images/mcq2.png" width = "100%">
#
#
# <img src="{{site.baseurl}}/images/mcqReview.png" width = "100%">
#
# ---
#
# ### Need to Work On
#
# - 3.6: Conditionals: 0%
# - 3.17: Algorithmic Efficiency: 0%
# - 3.9: Developing Algorithms: 50%
# - 1.4: Identifying and Correcting Errors: 71%
# - 2.1: Binary Numbers: 80%
# - 2.3: Extracting Information from Data: 86%
#
# ### How I Will Improve
#
# - Go over the College Board videos again
# - Review other MCQs
# - Further understand my mistakes and get a better knowledge in those categories
#
# ### [MCQ Corrections](http://127.0.0.1:4100/manahil_khan_2025/2025/03/03/MCQ_Corrections_IPYNB_2_.html){:target="_blank"}
#
#
# ---
#
# ## Retrospective
#
# - **Taking Interest in Other's Projects**
#
# ### Discord Basement Simulator
# <table style="width:100%; border-collapse: collapse; text-align: left;">
#   <tr style="background-color:rgba(139, 181, 207, 0.57);">
#     <th style="padding: 10px; border: 1px solid #ddd;">Purpose</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">Pros</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">Improvements</th>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Need to get our of basement, needs crypto and money.</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Unique, I liked the concept and thought it was very fun and interesting. Cool concept of mini games.</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Visuals could be a little more put together.</td>
#   </tr>
# </table>
#
# ---
#
# ### Legendary Motorsport
# <table style="width:100%; border-collapse: collapse; text-align: left;">
#   <tr style="background-color:rgba(139, 181, 207, 0.57);">
#     <th style="padding: 10px; border: 1px solid #ddd;">Purpose</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">Pros</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">Improvements</th>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">A resource for people who have an interest in cars. Can post and chat with others and view a variety of things related to the topic.</td>
#     <td style="padding: 10px; border: 1px solid #ddd;"> Looked like a professional website. Very nice frontend and styling, brings together the whole website.</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">UX flow, presentation skills.</td>
#   </tr>
# </table>
#
# ---
#
# ### Study Buddy
# <table style="width:100%; border-collapse: collapse; text-align: left;">
#   <tr style="background-color:rgba(139, 181, 207, 0.57);">
#     <th style="padding: 10px; border: 1px solid #ddd;">Purpose</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">Pros</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">Improvements</th>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">A resource for students to keep on track and plan their days. Helps them study and connect with others to learn.</td>
#     <td style="padding: 10px; border: 1px solid #ddd;"> Really nice design, very appealing. I thought it was a great idea too and could be very useful to real students.</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">Instead of letting everyone delete others posts make it just so admin can.</td>
#   </tr>
# </table>
#
# ---
#
# - **Practice Live Review:** I conducted a preliminary live review session with students from other Comp Sci periods as well as my team member to refine my ability to present key points concisely and effectively.
#
# - **Sent a summary of what I will be talking about 24 hours in advance of Live review in DM**
#
# ---
#
# - **Reflection on Strengths, Weaknesses & Next Steps**
#
#
# | Strengths                                              | Weaknesses                                               |
# |--------------------------------------------------------|----------------------------------------------------------|
# | Strong communication and collaboration skills          | Relying less on others                                   |
# | Determined to learn more and open to new possibilities | Coding skills                                            |
# | Organization through burndown lists                    | Need to practice condensing key points for presentations |
#
# ---
#
# - **Reflection on Project**
#
# | Strengths                                      | Weaknesses                                            |
# |------------------------------------------------|-------------------------------------------------------|
# | Strong debugging and problem-solving skills    | Visuals and flow of website                           |
# | Effective team collaboration and communication | Features could be more intertwined                    |
# | Ability to adapt to problems                   | Integration problems                                  |
#
# ### **Future Plans**
#
# | Strengths                                   | Next Steps                                              |
# |---------------------------------------------|---------------------------------------------------------|
# | Well-structured backend and API (CRUD)      | Improve UI responsiveness and optimize database queries |
# | Secure authentication system                | Implement more advanced user roles and permissions      |
# | Clean documentation                         | Add a tutorial or guide for new contributors            |
#
# ## Self Grade
#
# <table style="width:100%; border-collapse: collapse; text-align: left;">
#   <tr style="background-color:rgba(139, 181, 207, 0.57);">
#     <th style="padding: 10px; border: 1px solid #ddd;">Points</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">What I think I Earned</th>
#     <th style="padding: 10px; border: 1px solid #ddd;">Why?</th>
#   </tr>
#   <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">5 things you did over 12 weeks, Issues, burndown, presentation - 5 points</td>
#     <td style="padding: 10px; border: 1px solid #ddd;"> 4.7</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">I think I accomplished a lot over the trimester, however my coding still isn't perfect. My collaboration really helped me this tri and I feel I have greatly improved.</td>
#   </tr>
#     <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Full Stack Project Demo, including CPT requirement highlights, and N@tM feedback - 2 points</td>
#     <td style="padding: 10px; border: 1px solid #ddd;"> 1.8</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">I have full CRUD, however it took a lot of trial and error to get it to work with no errors.</td>
#   </tr>
#     <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Project Feature blog write up, using CPT/FRQ language - 1 point</td>
#     <td style="padding: 10px; border: 1px solid #ddd;"> 1</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">I had a complete in depth blog for my feature with all my CPT requirements and including FRQ language</td>
#   </tr>
#     <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">MCQ - 1 point</td>
#     <td style="padding: 10px; border: 1px solid #ddd;"> 1</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">I completed the MC and throughly went over each question. I also did a summary of what I need to work on and corrections for the questions I got wrong.</td>
#   </tr>
#     <tr>
#     <td style="padding: 10px; border: 1px solid #ddd;">Retrospective - 1 point</td>
#     <td style="padding: 10px; border: 1px solid #ddd;"> 0.8</td>
#     <td style="padding: 10px; border: 1px solid #ddd;">I went above and beyond the basic 9 points, I showed interest in other peoples projects, I practiced my review with others to ensure I was prepared, I sent a summary of my topics 24 hours before to let you see and overview, and lastly I talked about my personal strengths and weaknesses as well as my teams and our next steps.</td>
#   </tr>
# </table>
#
# ## Final Self Grade: 9.3/10
#
# This 12-week experience reinforced the importance of teamwork, problem-solving, and continuous learning. Through debugging challenges, sprint retrospectives, and live demos, I gained valuable insights into full-stack development. I look forward to refining our project based on feedback and tackling more complex programming challenges in the future!
