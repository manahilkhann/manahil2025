# %% [markdown]
# ---
# layout: post
# types: hacks
# title: Final Review
# description: My final review!
# toc: true
# comments: true
# ---

# %% [markdown]
# # LinkdIn

# %% [markdown]
# <a href="https://www.linkedin.com/in/manahil-khan-b00214367/" target="_blank" style="font-size: 24px; font-weight: bold;">
#   My LinkdIn
# </a>

# %% [markdown]
# # Overview of Projects
#
# <a href="https://prajnar123123213.github.io/powaydata_frontend/" target="_blank" style="font-size: 24px; font-weight: bold;">
#   Poway City
# </a>
#
# ## Description:
# Bringing our community together through local events, shared stories, and the beauty of Poway. This site is your go-to guide for upcoming gatherings, city highlights, and must-see tourist attractions. Whether you're a long-time resident or a curious visitor, explore everything our hometown has to offer—from scenic trails to family-friendly festivals—all in one place. We used HTML, CSS, and JavaScript to build a clean, user-friendly interface, and integrated APIs to dynamically pull in live event data and location-based recommendations, making the site both interactive and informative.
#
# ---
#
# <a href="https://prajnar123123213.github.io/datascience_frontend/" target="_blank" style="font-size: 24px; font-weight: bold;">
#   Data Science
# </a>
#
# ## Description:
# An interactive data science website where machine learning meets fun and functionality. Explore a variety of hands-on features, including a pet simulator powered by behavioral data, a Titanic survival predictor, a travel destination recommender, a college admissions predictor, and a disease survival estimator. Each tool is built using real-world datasets and ML models to help users understand and apply data science in meaningful ways.
#
# ---
#
# <a href="https://manahilkhann.github.io/manahil2025/2025/06/10/Data_Science_Feature_IPYNB_2_.html" target="_blank" style="font-size: 24px; font-weight: bold;">
#   My Feature's Code
# </a>

# %% [markdown]
# # Credentials
#
# | Credential | Event/Skill        |  Details                                                                                  |
# |--------------------|--------------------|-------------------------------------------------------------------------------------------------|
# | Certificate        | Basic Tools        | Utilized foundational tools (GitHub, GitPod, and terminal)                                      |
# | Certificate        | GitHub Pages       | Utilized GitHub Pages for organization and projects                                             |
# | Certificate        | Python Data Analysis | Applied Python to structure and interpret data for game scoring and logic in Binary Coders    |
# | Certificate        | API Development    | Built and integrated scoring and attempt APIs for DNA Dynamite and Binary Coders                 |
# | NFT                | Personalized Website | Unique design and implementation of GitHub Pages                                               |

# %% [markdown]
# # Homework Success
#
# <a href="https://manahilkhann.github.io/manahil2025/2025/04/21/Study_Plan_IPYNB_2_.html" target="_blank" style="font-size: 24px; font-weight: bold;">
#   Lesson Homeworks
# </a>

# %% [markdown]
# # N@TM
#
# <style>
#     .image-scroller {
#         width: 100%;
#         overflow-x: scroll;
#         overflow-y: hidden;
#         white-space: nowrap;
#         background-color:rgb(255, 255, 255);
#         border: 1px rgb(255, 255, 255);
#         border-radius: 10px;
#         box-shadow: 0 4px 8px 0 #F0F6F6, 0 6px 20px 0 #F0F6F6;
#         margin: 20px auto;
#         padding: 10px 0;
#     }
#     .image-scroller img {
#         display: inline-block;
#         width: 400px;
#         height: 300px;
#         margin-right: 10px;
#         border-radius: 5px;
#         object-fit: cover;
#     }
# </style>
# <div class="image-scroller">
#     <img src="{{ site.baseurl }}/images/N@TM4.png" alt="Team Photo">
#      <img src="{{ site.baseurl }}/images/N@TM5.png" alt="team photo 2" style="margin-left: 10px;">
#
# </div>
#
# - Shared our work with others
# - Presented and promoted our project to potential users
# - Practiced presentation skills to be confident, loud, and able to pitch your work

# %% [markdown]
# # Stats
#
# <a href="https://pages.opencodingsociety.com/dashboard" target="_blank" style="font-size: 24px; font-weight: bold;">
#   OCS Dashboard
# </a>
#
# <a href="https://github.com/manahilkhann" target="_blank" style="font-size: 24px; font-weight: bold;">
#   View my Github
# </a>
